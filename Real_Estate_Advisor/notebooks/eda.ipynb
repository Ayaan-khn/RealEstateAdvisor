# %%
import pandas as pd

df = pd.read_csv("../data/india_housing_prices.csv")

df.shape
df.head()
df.info()
df.isnull().sum()
df.duplicated().sum() #Count Duplicate Rows
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 23 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ID                              250000 non-null  int64
#  1   State                           250000 non-null  str
#  2   City                            250000 non-null  str
#  3   Locality                        250000 non-null  str
#  4   Property_Type                   250000 non-null  str
#  5   BHK                             250000 non-null  int64
#  6   Size_in_SqFt                    250000 non-null  int64
#  7   Price_in_Lakhs                  250000 non-null  float64
#  8   Price_per_SqFt                  250000 non-null  float64
#  9   Year_Built                      250000 non-null  int64
#  10  Furnished_Status                250000 non-null  str
#  11  Floor_No                        250000 non-null  int64
# ...

# %%
df.describe() #Summary statistics of numeric columns
# Out:
#                   ID            BHK   Size_in_SqFt  Price_in_Lakhs  \
# count  250000.000000  250000.000000  250000.000000   250000.000000
# mean   125000.500000       2.999396    2749.813216      254.586854
# std     72168.927986       1.415521    1300.606954      141.349921
# min         1.000000       1.000000     500.000000       10.000000
# 25%     62500.750000       2.000000    1623.000000      132.550000
# 50%    125000.500000       3.000000    2747.000000      253.870000
# 75%    187500.250000       4.000000    3874.000000      376.880000
# max    250000.000000       5.000000    5000.000000      500.000000
#
#        Price_per_SqFt     Year_Built       Floor_No   Total_Floors  \
# count   250000.000000  250000.000000  250000.000000  250000.000000
# mean         0.130597    2006.520012      14.966800      15.503004
# std          0.130747       9.808575       8.948047       8.671618
# min          0.000000    1990.000000       0.000000       1.000000
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# ID                                0
# State                             0
# City                              0
# Locality                          0
# Property_Type                     0
# BHK                               0
# Size_in_SqFt                      0
# Price_in_Lakhs                    0
# Price_per_SqFt                    0
# Year_Built                        0
# Furnished_Status                  0
# Floor_No                          0
# Total_Floors                      0
# Age_of_Property                   0
# Nearby_Schools                    0
# Nearby_Hospitals                  0
# Public_Transport_Accessibility    0
# Parking_Space                     0
# Security                          0
# Amenities                         0
# Facing                            0
# Owner_Type                        0
# Availability_Status               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.select_dtypes(include='string').nunique()
# Out:
# State                              20
# City                               42
# Locality                          500
# Property_Type                       3
# Furnished_Status                    3
# Public_Transport_Accessibility      3
# Parking_Space                       2
# Security                            2
# Amenities                         325
# Facing                              4
# Owner_Type                          3
# Availability_Status                 2
# dtype: int64

# %%
# “The dataset contains no missing values, no major data issues, and has strong diversity in categorical features like city, locality, and amenities, making it suitable for analysis.”

# %%
import pandas as pd

df = pd.read_csv("../data/india_housing_prices.csv")
#Bringing Raw Data Into Script

# %%
print("Duplicates:", df.duplicated().sum())
df = df.drop_duplicates()
#Removing All duplicates
# Out:
# Duplicates: 0

# %%
df = df.drop(columns=["ID"])
#dropping all useless columns

# %%
df["Age_of_Property"] = 2026 - df["Year_Built"]
#creating new id

# %%
df["Price_per_SqFt"] = (df["Price_in_Lakhs"] * 100000) / df["Size_in_SqFt"]
#normalized price metric

# %%
print(df.isnull().sum().sum())
print(df.shape)

#LOL sanity check
#Why?  ensure no missing values and shape is correct
# Out:
# 0
# (250000, 22)

# %%
df.to_csv("../data/cleaned_data.csv", index=False)

#saving all the changes now

# %%
# Load cleaned data
df = pd.read_csv("../data/cleaned_data.csv")

# 1) Shape
print("Shape:", df.shape)

# 2) Missing values
print("\nMissing values:\n", df.isnull().sum().sum())

# 3) Duplicates
print("\nDuplicates:", df.duplicated().sum())

# 4) Columns check
print("\nColumns:\n", df.columns)

# 5) Feature check
print("\nAge_of_Property exists:", "Age_of_Property" in df.columns)

# 6) Basic stats sanity
print("\nDescribe:\n", df.describe().head())
# Out:
# Shape: (250000, 22)
#
# Missing values:
#  0
#
# Duplicates: 0
#
# Columns:
#  Index(['State', 'City', 'Locality', 'Property_Type', 'BHK', 'Size_in_SqFt',
#        'Price_in_Lakhs', 'Price_per_SqFt', 'Year_Built', 'Furnished_Status',
#        'Floor_No', 'Total_Floors', 'Age_of_Property', 'Nearby_Schools',
#        'Nearby_Hospitals', 'Public_Transport_Accessibility', 'Parking_Space',
#        'Security', 'Amenities', 'Facing', 'Owner_Type', 'Availability_Status'],
#       dtype='str')
#
# Age_of_Property exists: True
#
# Describe:
#                   BHK   Size_in_SqFt  Price_in_Lakhs  Price_per_SqFt  \
# count  250000.000000  250000.000000   250000.000000   250000.000000
# mean        2.999396    2749.813216      254.586854    13058.281776
# std         1.415521    1300.606954      141.349921    13071.850480
# min         1.000000     500.000000       10.000000      202.247191
# 25%         2.000000    1623.000000      132.550000     4802.839710
#
# ...

# %%
#After preprocessing, I validated the dataset by checking for missing values, duplicates, and structural consistency. The dataset was clean and ready for analysis.

# %%
#“I maintained a separate cleaned dataset to preserve the integrity of the original data and ensure reproducibility.”
